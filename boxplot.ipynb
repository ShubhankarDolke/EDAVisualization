# %%
import seaborn as sns # for data visualization
import pandas as pd # for data analysis
import numpy as np # for numeric calculation
import matplotlib.pyplot as plt # for data visualization

# %%
data = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/EDALAB/SHUBHIMP/Case Study-New.xlsx")

# %%
data.head()
# Out:
#    Year    City          Product   Sales Staff            Channel      Month  \
# 0  2010  Bhopal           Laptop  Abhay Vaidya        Exhibitions 2010-04-01
# 1  2010  Bhopal  Landline phones  Abhay Vaidya   Department Store 2010-05-01
# 2  2010  Bhopal    Mobile Phones  Abhay Vaidya  Electronic Stores 2010-05-01
# 3  2010  Bhopal     Smart phones  Abhay Vaidya   Department Store 2010-05-01
# 4  2010  Bhopal     Smart phones  Abhay Vaidya  Electronic Stores 2010-05-01
#
#    Cost Price  Sale Price  Quantity  Discount %  Freight Rs  Returns qty  \
# 0       35000       49900       127           2    120015.0            1
# 1        1200        3200      1474           2     24763.2           18
# 2        3100        4500      1126           2     48868.4            3
# 3       12000       25300       641           2    107688.0            5
# 4       11200       23600      2901           2    454876.8           23
#
#    Total Sales
# 0      6337300
# 1      4716800
# 2      5067000
# 3     16217300
# 4     68463600

# %%
sns.boxplot(data=data, x="Quantity", y="City")
# Out:
# <Axes: xlabel='Quantity', ylabel='City'>
