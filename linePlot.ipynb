# %%
import seaborn as sns # for data visualization
import pandas as pd # for data analysis
import matplotlib.pyplot as plt # for data visualization

# %%
data = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/EDALAB/SHUBHIMP/Financial Sample.xlsx")
data
data2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/EDALAB/SHUBHIMP/insurance.csv")

# %%
sns.lineplot(x = "Month Number", y = "Profit", data=data,)
plt.show()

# %%
sns.lineplot( data=data2,)
plt.show()
